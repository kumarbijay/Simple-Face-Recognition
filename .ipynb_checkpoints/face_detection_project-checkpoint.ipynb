# %%
# !git clone https://github.com/gharnab/FACE-DETECT.git
# Out:
# fatal: destination path 'FACE-DETECT' already exists and is not an empty directory.

# %%
import pickle
from sklearn.preprocessing import LabelEncoder
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten
from keras.optimizers import Adam,RMSprop
from keras.models import Model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 6>()
#       4 import matplotlib.pyplot as plt
#       5 from sklearn.model_selection import train_test_split
# ----> 6 from keras.utils import to_categorical
#       7 from keras.models import Sequential
#       8 from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten
#
# File c:\users\kbija\appdata\local\programs\python\python38\lib\site-packages\keras\__init__.py:21, in <module>
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python import tf2
#      22 from keras import distribute
#      24 from keras import models
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
with open("FACE-DETECT/pickle_data/images.p","rb") as f:
  images = pickle.load(f)

with open("FACE-DETECT/pickle_data/labels.p","rb") as f:
  labels = pickle.load(f)

# %%
print(images.shape)
print(labels.shape)
print(set(labels))
# Out:
# (494, 100, 100)
# (494,)
# {'Malay', 'sambit', 'Arnab', 'Durga', 'Ashutosh'}

# %%
le = LabelEncoder()
labels = le.fit_transform(labels)

# %%
print(set(labels))
# Out:
# {0, 1, 2, 3, 4}

# %%
n_classes = len(set(labels))
label_mapping = le.inverse_transform(np.arange(n_classes))
print(label_mapping)
# Out:
# ['Arnab' 'Ashutosh' 'Durga' 'Malay' 'sambit']

# %%
for i in range(n_classes):
  print("person {} is {}".format(i,le.inverse_transform([i])))
# Out:
# person 0 is ['Arnab']
# person 1 is ['Ashutosh']
# person 2 is ['Durga']
# person 3 is ['Malay']
# person 4 is ['sambit']

# %%
fig,axes = plt.subplots(nrows=n_classes,ncols=5,figsize=(20,20))
fig.tight_layout()

for i in range(n_classes):

  for j in range(5): 
    axes [i][j].imshow(images[labels==i][np.random.randint(0,len(images[labels==i]))],cmap="gray")
    axes[i][j].axis("off")
    axes[i][j].set_title(label_mapping[i])

# %%
def preprocess(img):
  img = img.reshape(100,100,1)
  img = img/255
  return img

# %%
images = np.array(list(map(preprocess,images)))

# %%
print(images.shape)
# Out:
# (494, 100, 100, 1)

# %%
xtr,xts,ytr,yts = train_test_split(images,labels,test_size=0.1,random_state=0)

# %%
ytr = to_categorical(ytr,n_classes)
yts = to_categorical(yts,n_classes)

# %%
model = Sequential()
model.add(Conv2D(32,(5,5),input_shape=(100,100,1),strides=2,activation="relu"))
model.add(Conv2D(32,(5,5),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())

model.add(Dense(512,activation="relu"))
model.add(Dense(216,activation="relu"))
model.add(Dense(n_classes,activation="softmax"))
model.compile(RMSprop(learning_rate=1e-4),loss=["categorical_crossentropy"],metrics = ["accuracy"])

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 48, 48, 32)        832
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 44, 44, 32)        25632
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 18, 18, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 5184)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               2654720
# _________________________________________________________________
# dense_4 (Dense)              (None, 216)               110808
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 1085
# =================================================================
# Total params: 2,848,501
# Trainable params: 2,848,501
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(xtr,ytr,epochs=25,verbose=1,validation_data=(xts,yts))
# Out:
# Epoch 1/25
# 14/14 [==============================] - 6s 461ms/step - loss: 1.3677 - accuracy: 0.4482 - val_loss: 1.0183 - val_accuracy: 0.6800
# Epoch 2/25
# 14/14 [==============================] - 6s 453ms/step - loss: 0.6473 - accuracy: 0.8671 - val_loss: 0.3272 - val_accuracy: 0.9800
# Epoch 3/25
# 14/14 [==============================] - 6s 449ms/step - loss: 0.2501 - accuracy: 0.9414 - val_loss: 0.1158 - val_accuracy: 1.0000
# Epoch 4/25
# 14/14 [==============================] - 6s 451ms/step - loss: 0.0821 - accuracy: 0.9955 - val_loss: 0.0514 - val_accuracy: 1.0000
# Epoch 5/25
# 14/14 [==============================] - 6s 455ms/step - loss: 0.0681 - accuracy: 0.9797 - val_loss: 0.0903 - val_accuracy: 0.9800
# Epoch 6/25
# 14/14 [==============================] - 6s 454ms/step - loss: 0.0633 - accuracy: 0.9797 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 7/25
# 14/14 [==============================] - 6s 449ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.1225 - val_accuracy: 0.9600
# Epoch 8/25
# 14/14 [==============================] - 6s 447ms/step - loss: 0.0334 - accuracy: 0.9910 - val_loss: 0.8566 - val_accuracy: 0.7800
# Epoch 9/25
# 14/14 [==============================] - 6s 450ms/step - loss: 0.0555 - accuracy: 0.9865 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 10/25
# 14/14 [==============================] - 6s 448ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 11/25
# 14/14 [==============================] - 6s 452ms/step - loss: 0.0371 - accuracy: 0.9932 - val_loss: 0.0489 - val_accuracy: 0.9800
# Epoch 12/25
# 14/14 [==============================] - 6s 451ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 13/25
# 14/14 [==============================] - 6s 447ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 14/25
# 14/14 [==============================] - 6s 452ms/step - loss: 0.1328 - accuracy: 0.9752 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 15/25
# 14/14 [==============================] - 6s 449ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 16/25
# 14/14 [==============================] - 6s 453ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 17/25
# 14/14 [==============================] - 6s 452ms/step - loss: 9.7097e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 18/25
# 14/14 [==============================] - 6s 447ms/step - loss: 7.5993e-04 - accuracy: 1.0000 - val_loss: 6.1731e-04 - val_accuracy: 1.0000
# Epoch 19/25
# 14/14 [==============================] - 6s 448ms/step - loss: 5.2235e-04 - accuracy: 1.0000 - val_loss: 3.0539e-04 - val_accuracy: 1.0000
# Epoch 20/25
# 14/14 [==============================] - 6s 452ms/step - loss: 0.0469 - accuracy: 0.9910 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 21/25
# 14/14 [==============================] - 6s 450ms/step - loss: 6.3054e-04 - accuracy: 1.0000 - val_loss: 6.2205e-04 - val_accuracy: 1.0000
# Epoch 22/25
# 14/14 [==============================] - 6s 453ms/step - loss: 7.0914e-04 - accuracy: 1.0000 - val_loss: 7.0358e-04 - val_accuracy: 1.0000
# Epoch 23/25
# 14/14 [==============================] - 6s 451ms/step - loss: 3.2572e-04 - accuracy: 1.0000 - val_loss: 2.4785e-04 - val_accuracy: 1.0000
# Epoch 24/25
# 14/14 [==============================] - 6s 453ms/step - loss: 1.5468e-04 - accuracy: 1.0000 - val_loss: 1.5782e-04 - val_accuracy: 1.0000
# Epoch 25/25
# 14/14 [==============================] - 6s 451ms/step - loss: 1.3927e-04 - accuracy: 1.0000 - val_loss: 1.6263e-04 - val_accuracy: 1.0000

# %%
layer0 = Model(model.layers[0].input,model.layers[0].output)

# %%
features = layer0.predict(xts[0].reshape(1,100,100,1))

# %%
features.shape
# Out:
# (1, 48, 48, 32)

# %%
plt.figure(figsize=(10,15))
for i in range(32):
  axes = plt.subplot(8,4,i+1)
  plt.imshow(features[0,:,:,i])

# %%
model.save("FACE-DETECT.h5")
